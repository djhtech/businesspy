# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 19.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 15.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 28.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pathlib

# %%
# !pip install datetime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 8.8 MB/s eta 0:00:00
# ...

# %%
import pandas
# Out:
# /tmp/ipykernel_15292/3648170110.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
# !pip pandas --version
# Out:
# ERROR: unknown command "pandas"

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ----------------
# anyio                     4.2.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# bcc                       0.18.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.4
# Brlapi                    0.8.3
# certifi                   2020.6.20
# cffi                      1.16.0
# chardet                   4.0.0
# charset-normalizer        3.3.2
# chrome-gnome-shell        0.0.0
# click                     8.0.3
# colorama                  0.4.4
# comm                      0.2.1
# command-not-found         0.3
# cryptography              3.4.8
# cupshelpers               1.0
# DateTime                  5.4
# dbus-python               1.2.18
# ...

# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 17.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...

# %%
import pandas as pd

# %%
url = 'https://github.com/chris1610/pbpython/blob/master/data/2018_Sales_Total_v2.xlsx?raw=True'

# %%
df = pd.read_excel(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/my_project/venv/lib/python3.10/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel(2018_Sales_Total_v2.xlsx)
# Out:
#   Cell In[19], line 1
#     df = pd.read_excel(2018_Sales_Total_v2.xlsx)
#                            ^
# SyntaxError: invalid decimal literal

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 3.2 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# ...

# %%
df = pd.read_excel(2018_Sales_Total_v2.xlsx)
# Out:
#   Cell In[21], line 1
#     df = pd.read_excel(2018_Sales_Total_v2.xlsx)
#                            ^
# SyntaxError: invalid decimal literal

# %%
df = pd.read_excel(Sales_Total_2018_v2.xlsx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = pd.read_excel(Sales_Total_2018_v2.xlsx)
#
# NameError: name 'Sales_Total_2018_v2' is not defined

# %%
import pandas as pd

# %%
df = pd.read_excel(r'Sales_Total_2018_v2.xlsx', sheet_name='Sheet1')

# %%
df
# Out:
#       account number                         name       sku  quantity  \
# 0             740150                   Barton LLC  B1-20000        39
# 1             714466              Trantow-Barrows  S2-77896        -1
# 2             218895                    Kulas Inc  B1-69924        23
# 3             307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4             412290                Jerde-Hilpert  S2-34077         6
# ...              ...                          ...       ...       ...
# 1502          424914                White-Trantow  B1-69924        37
# 1503          424914                White-Trantow  S1-47412        16
# 1504          424914                White-Trantow  B1-86481        75
# 1505          424914                White-Trantow  S1-82801        20
# 1506          424914                White-Trantow  S2-83881       100
#
#       unit price  ext price                date
# 0          86.69    3380.91 2018-01-01 07:21:51
# ...

# %%
import qgrid
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import qgrid
#
# ModuleNotFoundError: No module named 'qgrid'

# %%
# !pip install ipywidgets

# %%
# !pip install qgrid
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.2/889.2 kB 6.2 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761253 sha256=4d8534e7b0f9019b59e2f8c2916c671bfdb508a8f98406262c551f73c94d626b
#   Stored in directory: /home/djh/.cache/pip/wheels/b2/28/9b/c1053eb92a506d814e21f415d6ce4beab694a3efed99b500bc
# Successfully built qgrid
# ...

# %%
widget = qgrid.show_grid(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 widget = qgrid.show_grid(df)
#
# NameError: name 'qgrid' is not defined

# %%
import qgrid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import qgrid
#
# File ~/Desktop/my_project/venv/lib/python3.10/site-packages/qgrid/__init__.py:3
#       1 from ._version import version_info, __version__  # noqa F401
# ----> 3 from .grid import (
#       4     enable,
#       5     disable,
#       6     set_defaults,
#       7     on,
#       8     off,
#       9     set_grid_option,
#      10     show_grid,
#      11     QgridWidget,
#      12     QGridWidget,
#      13 )
#      16 def _jupyter_nbextension_paths():
#      17     return [
#      18         {
#      19             "section": "notebook",
#    (...)
#      23         }
#      24     ]
#
# File ~/Desktop/my_project/venv/lib/python3.10/site-packages/qgrid/grid.py:524
#     520     else:
#     521         return str(x)
# --> 524 @widgets.register()
# ...

# %%
df
# Out:
#       account number                         name       sku  quantity  \
# 0             740150                   Barton LLC  B1-20000        39
# 1             714466              Trantow-Barrows  S2-77896        -1
# 2             218895                    Kulas Inc  B1-69924        23
# 3             307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4             412290                Jerde-Hilpert  S2-34077         6
# ...              ...                          ...       ...       ...
# 1502          424914                White-Trantow  B1-69924        37
# 1503          424914                White-Trantow  S1-47412        16
# 1504          424914                White-Trantow  B1-86481        75
# 1505          424914                White-Trantow  S1-82801        20
# 1506          424914                White-Trantow  S2-83881       100
#
#       unit price  ext price                date
# 0          86.69    3380.91 2018-01-01 07:21:51
# ...

# %%
widget = qgrid.show_grid(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 widget = qgrid.show_grid(df)
#
# NameError: name 'qgrid' is not defined

# %%
import qgrid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import qgrid
#
# File ~/Desktop/my_project/venv/lib/python3.10/site-packages/qgrid/__init__.py:3
#       1 from ._version import version_info, __version__  # noqa F401
# ----> 3 from .grid import (
#       4     enable,
#       5     disable,
#       6     set_defaults,
#       7     on,
#       8     off,
#       9     set_grid_option,
#      10     show_grid,
#      11     QgridWidget,
#      12     QGridWidget,
#      13 )
#      16 def _jupyter_nbextension_paths():
#      17     return [
#      18         {
#      19             "section": "notebook",
#    (...)
#      23         }
#      24     ]
#
# File ~/Desktop/my_project/venv/lib/python3.10/site-packages/qgrid/grid.py:524
#     520     else:
#     521         return str(x)
# --> 524 @widgets.register()
# ...

# %%
qgrid.show_grid(df, precision=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 qgrid.show_grid(df, precision=2)
#
# NameError: name 'qgrid' is not defined

# %%
jupyter nbextension enable --py --sys-prefix qgrid
# Out:
#   Cell In[37], line 1
#     jupyter nbextension enable --py --sys-prefix qgrid
#             ^
# SyntaxError: invalid syntax

# %%
history
# Out:
# %load_ext autoreload
# %autoreload 2
# import pandas
# pandas.__version__
# import pandas
# import pandas as pd
# !pip install pandas
# !pip install pathlib
# !pip install datetime
# import pandas
# !pip pandas --version
# !pip list
# !pip install pyarrow
# import pandas
# url = 'https://github.com/chris1610/pbpython/blob/master/data/2018_Sales_Total_v2.xlsx?raw=True'
# df = pd.read_excel(url)
# import pandas as pd
# url = 'https://github.com/chris1610/pbpython/blob/master/data/2018_Sales_Total_v2.xlsx?raw=True'
# df = pd.read_excel(url)
# import pandas as pd
# df = pd.read_excel(2018_Sales_Total_v2.xlsx)
# !pip install openpyxl
# df = pd.read_excel(2018_Sales_Total_v2.xlsx)
# df = pd.read_excel(Sales_Total_2018_v2.xlsx)
# import pandas as pd
# df = pd.read_excel(Sales_Total_2018_v2.xlsx)
# df = pd.read_excel(Sales_Total_2018_v2.xlsx, sheet_name='Sheet1')
# df = pd.read_excel(r'Sales_Total_2018_v2.xlsx', sheet_name='Sheet1')
# df
# import qgrid
# !pip install ipywidgets
# ...

# %%
df = pd.read_excel(r'Sales_Total_2018_v2.xlsx', sheet_name='Sheet1')

# %%
df
# Out:
#       account number                         name       sku  quantity  \
# 0             740150                   Barton LLC  B1-20000        39
# 1             714466              Trantow-Barrows  S2-77896        -1
# 2             218895                    Kulas Inc  B1-69924        23
# 3             307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4             412290                Jerde-Hilpert  S2-34077         6
# ...              ...                          ...       ...       ...
# 1502          424914                White-Trantow  B1-69924        37
# 1503          424914                White-Trantow  S1-47412        16
# 1504          424914                White-Trantow  B1-86481        75
# 1505          424914                White-Trantow  S1-82801        20
# 1506          424914                White-Trantow  S2-83881       100
#
#       unit price  ext price                date
# 0          86.69    3380.91 2018-01-01 07:21:51
# ...

# %%
df = pd.read_excel(r'Sales_Total_2018_v2.xlsx', header=0, usecols=[0,1,2,3,4,5,6])

# %%
df
# Out:
#                              name       sku  quantity  unit price  ext price  \
# 0                      Barton LLC  B1-20000        39       86.69    3380.91
# 1                 Trantow-Barrows  S2-77896        -1       63.16     -63.16
# 2                       Kulas Inc  B1-69924        23       90.70    2086.10
# 3     Kassulke, Ondricka and Metz  S1-65481        41       21.05     863.05
# 4                   Jerde-Hilpert  S2-34077         6       83.21     499.26
# ...                           ...       ...       ...         ...        ...
# 1502                White-Trantow  B1-69924        37       42.77    1582.49
# 1503                White-Trantow  S1-47412        16       65.58    1049.28
# 1504                White-Trantow  B1-86481        75       28.89    2166.75
# 1505                White-Trantow  S1-82801        20       95.75    1915.00
# 1506                White-Trantow  S2-83881       100       88.19    8819.00
#
#                     date
# ...
